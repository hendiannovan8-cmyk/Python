# %% [markdown]
# **Check Version**

# %%
import sys
print(sys.version)
# Out:
# 3.14.7 (tags/v3.14.7:823f032, Aug  5 2026, 10:51:32) [MSC v.1944 64 bit (AMD64)]

# %% [markdown]
# **Indentation**

# %%
#Indentasi pada python sangat penting agar kode bisa berjalan
if 5 > 2:
    print("True")
if 10 > 5:
    print("Great")
# Out:
# True
# Great

# %% [markdown]
# **Variable & Comment**

# %%
#python tidak mendeklarsikan variable
y = 5
x = "Me"
print(x)
print(y)

# %%
#Casting (menentukan tipe data)
x = str(3)
y = int(3)
z = float(3)

print(x)
print(y)
print(z)

# %%
#type (menentukan tipe data)
#Variabel string dapat dideklarasikan dengan menggunakan tanda kutip tunggal atau ganda
#Peka terhadap Huruf Besar/Kecil

x = 5
y = "John"
print(type(x))
print(type(y))

# %% [markdown]
# **Statements**

# %%
#python juga bisa mengeksekusi sabuah intruksi yang bisa disebut juga dengan Pernyataan (Statement).
print("Hello My World!!")
# Out:
# Hello My World!!

# %%
# Apabila ada banyak Statement
print("1. Saya adalah seorang Programer dari Indonesia.")
print("2. Mungkin ini pertama kali saya belajar mengenai hal seperti ini.")
print("3. Dengan begini saya akan menekuni pengajaran ini samaai aku bisa berhasil mencapai tujuan saya.")
# Out:
# 1. Saya adalah seorang Programer dari Indonesia.
# 2. Mungkin ini pertama kali saya belajar mengenai hal seperti ini.
# 3. Dengan begini saya akan menekuni pengajaran ini samaai aku bisa berhasil mencapai tujuan saya.

# %%
# Cara kedua apabila ada banyak statement
print("Saya adalah A"); print("Saya adalah B"); print("Saya adalah C")
# Out:
# Saya adalah A
# Saya adalah B
# Saya adalah C

# %% [markdown]
# **Print**

# %%
# Mencetak TEKS tanpa harus menambah garis baru
print("Halo saya adalah ", end="seorang programer")
# Out:
# Halo saya adalah seorang programer

# %%
# Mencetak ANGKA pada python
print(3455)
print(12 + 12)
print("saya berumur", 20, "tahun")
# Out:
# 3455
# 24
# saya berumur 20 tahun
